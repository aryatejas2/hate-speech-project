# %%
import pandas as pd
import os

# %%
dir_path = "C:\\Users\\Tejas\\Desktop\\Capstone\\DatasetsCleaned\\UniformClasses\\V2\\train"

# %%
file_names = []
for files in os.listdir(dir_path):
    file_names.append(files)

# %%
print(file_names)
# Out:
# ['davidson_train.csv', 'hasoc_train.csv', 'hateval_train.csv', 'hatexplain_train.csv', 'ohc_train.csv', 'olid_train.csv', 'tcc_train.csv', 'trac_train.csv']

# %%
davidson = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\davidson2017.csv')
hasoc = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\hasoc.csv')
hateval = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\hateval2019.csv')
olid = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\olid-training-v1.0.csv')
trac = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\trac.csv')
gab = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\gab.csv')
reddit = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\reddit.csv')
hatexplain = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\hatexplain.csv')
tcc = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\tcc.csv')

# %%
## Combining Datasets

leave_davidson = pd.concat([hasoc, hateval, olid, trac, gab, reddit, hatexplain, tcc])
leave_davidson
# Out:
#                                                      Text Class
# 0       west bengal doctor crisi protest doctor agre m...   NOT
# 1        million peopl forc leav home      read   refu...   NOT
# 2                          came saw  look fort good luck    NOT
# 3       well get brexit deliv octob     help build mov...   NOT
# 4       fuck go back dark age cow ibnliverealtim rape ...   OFF
# ...                                                   ...   ...
# 159566  second time ask view complet contradict covera...   NOT
# 159567                asham horribl thing put talk page     NOT
# 159568  spitzer umm there actual articl prostitut ring...   NOT
# 159569  look like actual put speedi first version dele...   NOT
# 159570   realli dont think understand  came idea bad r...   NOT
#
# [244449 rows x 2 columns]

# %%
leave_davidson.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_davidson.csv")

# %%
leave_hasoc = pd.concat([davidson, hateval, olid, trac, gab, reddit, hatexplain, tcc])
leave_hasoc
# Out:
#                                                      Text Class
# 0        rt mayasolov woman shouldnt complain clean ho...   NOT
# 1        rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2        rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3                  rt cganderson vivabas look like tranni   OFF
# 4        rt shenikarobert shit hear might true might f...   OFF
# ...                                                   ...   ...
# 159566  second time ask view complet contradict covera...   NOT
# 159567                asham horribl thing put talk page     NOT
# 159568  spitzer umm there actual articl prostitut ring...   NOT
# 159569  look like actual put speedi first version dele...   NOT
# 159570   realli dont think understand  came idea bad r...   NOT
#
# [262227 rows x 2 columns]

# %%
leave_hasoc.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_hasoc.csv")

# %%
leave_hateval = pd.concat([davidson, hasoc, olid, trac, gab, reddit, hatexplain, tcc])
leave_hateval
# Out:
#                                                      Text Class
# 0        rt mayasolov woman shouldnt complain clean ho...   NOT
# 1        rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2        rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3                  rt cganderson vivabas look like tranni   OFF
# 4        rt shenikarobert shit hear might true might f...   OFF
# ...                                                   ...   ...
# 159566  second time ask view complet contradict covera...   NOT
# 159567                asham horribl thing put talk page     NOT
# 159568  spitzer umm there actual articl prostitut ring...   NOT
# 159569  look like actual put speedi first version dele...   NOT
# 159570   realli dont think understand  came idea bad r...   NOT
#
# [256232 rows x 2 columns]

# %%
leave_hateval.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_hateval.csv")

# %%
leave_olid = pd.concat([davidson, hasoc, hateval, trac, gab, reddit, hatexplain, tcc])
leave_olid
# Out:
#                                                      Text Class
# 0        rt mayasolov woman shouldnt complain clean ho...   NOT
# 1        rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2        rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3                  rt cganderson vivabas look like tranni   OFF
# 4        rt shenikarobert shit hear might true might f...   OFF
# ...                                                   ...   ...
# 159566  second time ask view complet contradict covera...   NOT
# 159567                asham horribl thing put talk page     NOT
# 159568  spitzer umm there actual articl prostitut ring...   NOT
# 159569  look like actual put speedi first version dele...   NOT
# 159570   realli dont think understand  came idea bad r...   NOT
#
# [255992 rows x 2 columns]

# %%
leave_olid.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_olid.csv")

# %%
leave_trac = pd.concat([davidson, hasoc, hateval, olid, gab, reddit, hatexplain, tcc])
leave_trac
# Out:
#                                                      Text Class
# 0        rt mayasolov woman shouldnt complain clean ho...   NOT
# 1        rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2        rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3                  rt cganderson vivabas look like tranni   OFF
# 4        rt shenikarobert shit hear might true might f...   OFF
# ...                                                   ...   ...
# 159566  second time ask view complet contradict covera...   NOT
# 159567                asham horribl thing put talk page     NOT
# 159568  spitzer umm there actual articl prostitut ring...   NOT
# 159569  look like actual put speedi first version dele...   NOT
# 159570   realli dont think understand  came idea bad r...   NOT
#
# [265231 rows x 2 columns]

# %%
leave_trac.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_trac.csv")

# %%
leave_gab = pd.concat([davidson, hasoc, hateval, olid, trac, reddit, hatexplain, tcc])
leave_gab
# Out:
#                                                      Text Class
# 0        rt mayasolov woman shouldnt complain clean ho...   NOT
# 1        rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2        rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3                  rt cganderson vivabas look like tranni   OFF
# 4        rt shenikarobert shit hear might true might f...   OFF
# ...                                                   ...   ...
# 159566  second time ask view complet contradict covera...   NOT
# 159567                asham horribl thing put talk page     NOT
# 159568  spitzer umm there actual articl prostitut ring...   NOT
# 159569  look like actual put speedi first version dele...   NOT
# 159570   realli dont think understand  came idea bad r...   NOT
#
# [252494 rows x 2 columns]

# %%
leave_gab.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_gab.csv")

# %%
leave_reddit = pd.concat([davidson, hasoc, hateval, olid, trac, gab, hatexplain, tcc])
leave_reddit
# Out:
#                                                      Text Class
# 0        rt mayasolov woman shouldnt complain clean ho...   NOT
# 1        rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2        rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3                  rt cganderson vivabas look like tranni   OFF
# 4        rt shenikarobert shit hear might true might f...   OFF
# ...                                                   ...   ...
# 159566  second time ask view complet contradict covera...   NOT
# 159567                asham horribl thing put talk page     NOT
# 159568  spitzer umm there actual articl prostitut ring...   NOT
# 159569  look like actual put speedi first version dele...   NOT
# 159570   realli dont think understand  came idea bad r...   NOT
#
# [257562 rows x 2 columns]

# %%
leave_reddit.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_reddit.csv")

# %%
leave_hatexplain = pd.concat([davidson, hasoc, hateval, olid, trac, gab, reddit, tcc])
leave_reddit
# Out:
#                                                      Text Class
# 0        rt mayasolov woman shouldnt complain clean ho...   NOT
# 1        rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2        rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3                  rt cganderson vivabas look like tranni   OFF
# 4        rt shenikarobert shit hear might true might f...   OFF
# ...                                                   ...   ...
# 159566  second time ask view complet contradict covera...   NOT
# 159567                asham horribl thing put talk page     NOT
# 159568  spitzer umm there actual articl prostitut ring...   NOT
# 159569  look like actual put speedi first version dele...   NOT
# 159570   realli dont think understand  came idea bad r...   NOT
#
# [257562 rows x 2 columns]

# %%
leave_hatexplain.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_hatexplain.csv")

# %%
leave_tcc = pd.concat([davidson, hasoc, hateval, olid, trac, gab, reddit, hatexplain])
leave_tcc
# Out:
#                                                     Text Class
# 0       rt mayasolov woman shouldnt complain clean ho...   NOT
# 1       rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2       rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3                 rt cganderson vivabas look like tranni   OFF
# 4       rt shenikarobert shit hear might true might f...   OFF
# ...                                                  ...   ...
# 19219      unpopular opinion nazi probabl best cult ever   OFF
# 19220                             nice ghetto rim faggot   OFF
# 19221    prophet muhammad saw say full neighbour slee...   NOT
# 19222  german blame bloodsh  fabric matrix break find...   OFF
# 19223  gab onlin ghetto right wing conserv product ho...   NOT
#
# [109661 rows x 2 columns]

# %%
leave_tcc.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_tcc.csv")

# %%
leave_none = pd.concat([davidson, hasoc, hateval, olid, trac, gab, reddit, hatexplain, tcc])

# %%
leave_none
# Out:
#                                                      Text Class
# 0        rt mayasolov woman shouldnt complain clean ho...   NOT
# 1        rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2        rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3                  rt cganderson vivabas look like tranni   OFF
# 4        rt shenikarobert shit hear might true might f...   OFF
# ...                                                   ...   ...
# 159566  second time ask view complet contradict covera...   NOT
# 159567                asham horribl thing put talk page     NOT
# 159568  spitzer umm there actual articl prostitut ring...   NOT
# 159569  look like actual put speedi first version dele...   NOT
# 159570   realli dont think understand  came idea bad r...   NOT
#
# [269232 rows x 2 columns]

# %%
leave_none.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\combined.csv")

# %%
print(len(davidson) + len(leave_davidson))
print(len(hasoc) + len(leave_hasoc))
print(len(hateval) + len(leave_hateval))
print(len(olid) + len(leave_olid))
print(len(trac) + len(leave_trac))
print(len(gab) + len(leave_gab))
print(len(reddit) + len(leave_reddit))
print(len(hatexplain) + len(leave_hatexplain))
print(len(tcc) + len(leave_tcc))
# Out:
# 269232
# 269232
# 269232
# 269232
# 269232
# 269232
# 269232
# 269232
# 269232
