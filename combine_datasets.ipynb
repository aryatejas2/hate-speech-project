# %%
import pandas as pd
import os

# %%
dir_path = "C:\\Users\\Tejas\\Desktop\\Capstone\\DatasetsCleaned\\UniformClasses\\Clean"

# %%
file_names = []
for files in os.listdir(dir_path):
    file_names.append(files)

# %%
print(file_names)
# Out:
# ['davidson2017.csv', 'gab.csv', 'hasoc.csv', 'hateval2019.csv', 'olid-training-v1.0.csv', 'reddit.csv', 'trac.csv']

# %%
davidson = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\davidson2017.csv')
hasoc = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\hasoc.csv')
hateval = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\hateval2019.csv')
olid = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\olid-training-v1.0.csv')
trac = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\trac.csv')
gab = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\gab.csv')
reddit = pd.read_csv(r'C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\UniformClasses\Clean\reddit.csv')

# %%
## Combining Datasets

leave_davidson = pd.concat([hasoc, hateval, olid, trac, gab, reddit])
leave_davidson
# Out:
#        Unnamed: 0                                               Text Class
# 0               0  west bengal doctor crisi protest doctor agre m...   NOT
# 1               1   million peopl forc leav home      read   refu...   NOT
# 2               2                     came saw  look fort good luck    NOT
# 3               3  well get brexit deliv octob     help build mov...   NOT
# 4               4  fuck go back dark age cow ibnliverealtim rape ...   OFF
# ...           ...                                                ...   ...
# 11665       11665   \t\t\tshe wont  video evid shes crazi  yall n...   NOT
# 11666       11666   \t\t\t\tno  wasnt video evid famili poor kid ...   NOT
# 11667       11667                     \t\t\t\twoman crazi women unit   NOT
# 11668       11668   \t\tnobodi care woman attempt destroy life ch...   NOT
# 11669       11669                                                NaN   NOT
#
# [65654 rows x 3 columns]

# %%
leave_davidson.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_davidson.csv")

# %%
leave_hasoc = pd.concat([davidson, hateval, olid, trac, gab, reddit])
leave_hasoc
# Out:
#        Unnamed: 0                                               Text Class
# 0               0   rt mayasolov woman shouldnt complain clean ho...   NOT
# 1               1   rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2               2   rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3               3             rt cganderson vivabas look like tranni   OFF
# 4               4   rt shenikarobert shit hear might true might f...   OFF
# ...           ...                                                ...   ...
# 11665       11665   \t\t\tshe wont  video evid shes crazi  yall n...   NOT
# 11666       11666   \t\t\t\tno  wasnt video evid famili poor kid ...   NOT
# 11667       11667                     \t\t\t\twoman crazi women unit   NOT
# 11668       11668   \t\tnobodi care woman attempt destroy life ch...   NOT
# 11669       11669                                                NaN   NOT
#
# [83432 rows x 3 columns]

# %%
leave_hasoc.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_hasoc.csv")

# %%
leave_hateval = pd.concat([davidson, hasoc, olid, trac, gab, reddit])
leave_hateval
# Out:
#        Unnamed: 0                                               Text Class
# 0               0   rt mayasolov woman shouldnt complain clean ho...   NOT
# 1               1   rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2               2   rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3               3             rt cganderson vivabas look like tranni   OFF
# 4               4   rt shenikarobert shit hear might true might f...   OFF
# ...           ...                                                ...   ...
# 11665       11665   \t\t\tshe wont  video evid shes crazi  yall n...   NOT
# 11666       11666   \t\t\t\tno  wasnt video evid famili poor kid ...   NOT
# 11667       11667                     \t\t\t\twoman crazi women unit   NOT
# 11668       11668   \t\tnobodi care woman attempt destroy life ch...   NOT
# 11669       11669                                                NaN   NOT
#
# [77437 rows x 3 columns]

# %%
leave_hateval.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_hateval.csv")

# %%
leave_olid = pd.concat([davidson, hasoc, hateval, trac, gab, reddit])
leave_olid
# Out:
#        Unnamed: 0                                               Text Class
# 0               0   rt mayasolov woman shouldnt complain clean ho...   NOT
# 1               1   rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2               2   rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3               3             rt cganderson vivabas look like tranni   OFF
# 4               4   rt shenikarobert shit hear might true might f...   OFF
# ...           ...                                                ...   ...
# 11665       11665   \t\t\tshe wont  video evid shes crazi  yall n...   NOT
# 11666       11666   \t\t\t\tno  wasnt video evid famili poor kid ...   NOT
# 11667       11667                     \t\t\t\twoman crazi women unit   NOT
# 11668       11668   \t\tnobodi care woman attempt destroy life ch...   NOT
# 11669       11669                                                NaN   NOT
#
# [77197 rows x 3 columns]

# %%
leave_olid.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_olid.csv")

# %%
leave_trac = pd.concat([davidson, hasoc, hateval, olid, gab, reddit])
leave_trac
# Out:
#        Unnamed: 0                                               Text Class
# 0               0   rt mayasolov woman shouldnt complain clean ho...   NOT
# 1               1   rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2               2   rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3               3             rt cganderson vivabas look like tranni   OFF
# 4               4   rt shenikarobert shit hear might true might f...   OFF
# ...           ...                                                ...   ...
# 11665       11665   \t\t\tshe wont  video evid shes crazi  yall n...   NOT
# 11666       11666   \t\t\t\tno  wasnt video evid famili poor kid ...   NOT
# 11667       11667                     \t\t\t\twoman crazi women unit   NOT
# 11668       11668   \t\tnobodi care woman attempt destroy life ch...   NOT
# 11669       11669                                                NaN   NOT
#
# [86436 rows x 3 columns]

# %%
leave_trac.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_trac.csv")

# %%
leave_gab = pd.concat([davidson, hasoc, hateval, olid, trac, reddit])
leave_gab
# Out:
#        Unnamed: 0                                               Text Class
# 0               0   rt mayasolov woman shouldnt complain clean ho...   NOT
# 1               1   rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2               2   rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3               3             rt cganderson vivabas look like tranni   OFF
# 4               4   rt shenikarobert shit hear might true might f...   OFF
# ...           ...                                                ...   ...
# 11665       11665   \t\t\tshe wont  video evid shes crazi  yall n...   NOT
# 11666       11666   \t\t\t\tno  wasnt video evid famili poor kid ...   NOT
# 11667       11667                     \t\t\t\twoman crazi women unit   NOT
# 11668       11668   \t\tnobodi care woman attempt destroy life ch...   NOT
# 11669       11669                                                NaN   NOT
#
# [73699 rows x 3 columns]

# %%
leave_gab.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_gab.csv")

# %%
leave_reddit = pd.concat([davidson, hasoc, hateval, olid, trac, gab])
leave_reddit
# Out:
#        Unnamed: 0                                               Text Class
# 0               0   rt mayasolov woman shouldnt complain clean ho...   NOT
# 1               1   rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2               2   rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3               3             rt cganderson vivabas look like tranni   OFF
# 4               4   rt shenikarobert shit hear might true might f...   OFF
# ...           ...                                                ...   ...
# 16733       16733                                                NaN   NOT
# 16734       16734                                                NaN   NOT
# 16735       16735   \ti routin suspend say fuck ban call promin l...   NOT
# 16736       16736                    \t\tthey got drop cunt bomb lot   NOT
# 16737       16737                                                NaN   NOT
#
# [78767 rows x 3 columns]

# %%
leave_reddit.to_csv(r"C:\Users\Tejas\Desktop\Capstone\DatasetsCleaned\LeaveOneOut" + "\leave_reddit.csv")

# %%
leave_none = pd.concat([davidson, hasoc, hateval, olid, trac, gab, reddit])

# %%
leave_none
# Out:
#        Unnamed: 0                                               Text Class
# 0               0   rt mayasolov woman shouldnt complain clean ho...   NOT
# 1               1   rt  boy dat coldtyga dwn bad cuffin dat hoe  ...   OFF
# 2               2   rt urkindofbrand dawg rt  ever fuck bitch sta...   OFF
# 3               3             rt cganderson vivabas look like tranni   OFF
# 4               4   rt shenikarobert shit hear might true might f...   OFF
# ...           ...                                                ...   ...
# 11665       11665   \t\t\tshe wont  video evid shes crazi  yall n...   NOT
# 11666       11666   \t\t\t\tno  wasnt video evid famili poor kid ...   NOT
# 11667       11667                     \t\t\t\twoman crazi women unit   NOT
# 11668       11668   \t\tnobodi care woman attempt destroy life ch...   NOT
# 11669       11669                                                NaN   NOT
#
# [90437 rows x 3 columns]

# %%
print(len(davidson) + len(leave_davidson))
print(len(hasoc) + len(leave_hasoc))
print(len(hateval) + len(leave_hateval))
print(len(olid) + len(leave_olid))
print(len(trac) + len(leave_trac))
print(len(gab) + len(leave_gab))
print(len(reddit) + len(leave_reddit))
# Out:
# 90437
# 90437
# 90437
# 90437
# 90437
# 90437
# 90437
